# %% [markdown]
# ## Conditional Statements

# %%
raining = False
muddy = True

if raining == True:
  print('It is raining.')
  print("Don't forget to take an umbrella!")
  if muddy == True:
    print('The streets are muddy.')
    print('Wear your boots!')
  else:
    print('The streets are dry.')
else:
  print('It is not raining.')
  print('Enjoy your day!')
# Out:
# It is not raining.
# Enjoy your day!

# %%
USD = 1150
Available = True

if (USD > 1000) and (Available == True):
  print('Build new pc')
elif (USD > 500) and (Available == True):
  print('Buy Only GPU')
elif (USD > 300) and (Available == True):
  print('Buy processor and Cooler')
else:
  print('Save money')
# Out:
# Build new pc
