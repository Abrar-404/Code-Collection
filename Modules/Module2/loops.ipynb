# %% [markdown]
# ## For Loop

# %%
for i in range(1,5):
  for j in range(1, 4):
    print(i, j)
# Out:
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3
# 4 1
# 4 2
# 4 3

# %% [markdown]
# ## While Loop

# %%
count = 1

while count < 10:
  print(count, 'Hello World')
  count += 1
# Out:
# 1 Hello World
# 2 Hello World
# 3 Hello World
# 4 Hello World
# 5 Hello World
# 6 Hello World
# 7 Hello World
# 8 Hello World
# 9 Hello World
