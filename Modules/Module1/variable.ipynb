# %%
phone_number = 123456789
print(phone_number)
# Out:
# 123456789

# %%
name1 = "John Doe"
print(name1)
# Out:
# John Doe

# %%
age = 20
height = 5.6
name2 = "Jane Doe"
is_passed = True

print(type(age), type(height), type(name2), type(is_passed))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
