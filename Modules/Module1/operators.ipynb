# %%
x = 10; y = 3

sum = x + y
sub = x - y
div = round(x / y, 2)
mult = x * y
rem = x % y

print(f"Sum: {sum} Sub: {sub} Div: {div} Mult: {mult} Rem: {rem}")
# Out:
# Sum: 13 Sub: 7 Div: 3.33 Mult: 30 Rem: 1
