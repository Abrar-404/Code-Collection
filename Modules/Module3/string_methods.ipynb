# %% [markdown]
# ## Length

# %%
string  = "Welcome to my github repository. Welcome" 

processed_string = string.lower()


print(len(string))

print("github" in processed_string)

# find_idx = processed_string.find("Welcome")
find_idx = processed_string.rfind("welcome")

print(find_idx)
# Out:
# 40
# True
# 33

# %% [markdown]
# ## Join

# %%
prompt = "what is Phitron ?"

tokens = prompt.split()

print(type(tokens))


sentence = "-".join(tokens)

print(type(sentence))
# Out:
# <class 'list'>
# <class 'str'>
